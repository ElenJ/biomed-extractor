# %% [markdown]
# # Development script for testing PICO extraction from clinical trials data

# %%
import os
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1" # suppresses Huggingface warning of storing data rather than symlinking it
from transformers import AutoTokenizer, AutoModelForPreTraining, pipeline
import pandas as pd

import sys
sys.path.append('../../')
# load functions for import of clinicaltrials.gov data written previously
from app.data.loader import load_trials_json, extract_from_clinicaltrials

# extractive summarization with textrank:
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

#import nltk
#nltk.download('punkt_tab') # needed for first time usage? Is being downloaded into user folder --> TODO: check out if works with dockerization and if it works with 'punkt' only

# %%
# Load BioM-ELECTRA-Base-PICO model directly
# TODO: clean up C:\Users\USER\.cache\huggingface\hub, deleting unneeded models
# tokenizer = AutoTokenizer.from_pretrained("kamalkraj/BioELECTRA-PICO")
# model = AutoModelForPreTraining.from_pretrained("kamalkraj/BioELECTRA-PICO")
ner_pipeline = pipeline("token-classification", 
                        model="kamalkraj/BioELECTRA-PICO",
                        aggregation_strategy="simple")
# Out:
# Some weights of ElectraForPreTraining were not initialized from the model checkpoint at kamalkraj/BioELECTRA-PICO and are newly initialized: ['discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu

# %%
# TEsting mini-models for NER
#ner_pipeline = pipeline("token-classification", model="nlpie/bio-mobilebert")      # only has LABEL_0, LABEL_1 as labels, not PICO
#ner_pipeline = pipeline("token-classification", model="nlpie/compact-biobert")  # only has LABEL_0, LABEL_1 as labels, not PICO
#ner_pipeline = pipeline("token-classification", model="nlpie/bio-distilbert-cased")  # only has LABEL_0, LABEL_1 as labels, not PICO
#ner_pipeline = pipeline("token-classification", model="nlpie/bio-tinybert")  # only has LABEL_0, LABEL_1 as labels, not PICO
# ner_pipeline = pipeline("token-classification", model="nlpie/distil-biobert") # only has LABEL_0, LABEL_1 as labels, not PICO
#ner_pipeline = pipeline("token-classification", model="nlpie/tiny-biobert")  # only has LABEL_0, LABEL_1 as labels, not PICO
# Out:
# config.json:   0%|          | 0.00/840 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/55.6M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at nlpie/tiny-biobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/55.6M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# [{'entity': 'LABEL_0',
#   'score': np.float32(0.53955513),
#   'index': 1,
#   'word': 'This',
#   'start': 0,
#   'end': 4},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52265954),
#   'index': 2,
#   'word': 'will',
#   'start': 5,
#   'end': 9},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.55467814),
#   'index': 3,
#   'word': 'be',
#   'start': 10,
#   'end': 12},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52197886),
#   'index': 4,
#   'word': 'a',
#   'start': 13,
#   'end': 14},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53868324),
#   'index': 5,
#   'word': 'double',
#   'start': 15,
#   'end': 21},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50593114),
#   'index': 6,
#   'word': 'blind',
#   'start': 22,
#   'end': 27},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51071393),
#   'index': 7,
#   'word': ',',
#   'start': 27,
#   'end': 28},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5679425),
#   'index': 8,
#   'word': 'place',
#   'start': 29,
#   'end': 34},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53768367),
#   'index': 9,
#   'word': '##bo',
#   'start': 34,
#   'end': 36},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5379257),
#   'index': 10,
#   'word': 'controlled',
#   'start': 37,
#   'end': 47},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5368629),
#   'index': 11,
#   'word': 'study',
#   'start': 48,
#   'end': 53},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.558233),
#   'index': 12,
#   'word': 'of',
#   'start': 54,
#   'end': 56},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5428555),
#   'index': 13,
#   'word': 'C',
#   'start': 57,
#   'end': 58},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5671135),
#   'index': 14,
#   'word': '-',
#   'start': 58,
#   'end': 59},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5668153),
#   'index': 15,
#   'word': '107',
#   'start': 59,
#   'end': 62},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5345028),
#   'index': 16,
#   'word': '##3',
#   'start': 62,
#   'end': 63},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5069198),
#   'index': 17,
#   'word': 'to',
#   'start': 64,
#   'end': 66},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5428707),
#   'index': 18,
#   'word': 'evaluate',
#   'start': 67,
#   'end': 75},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5528627),
#   'index': 19,
#   'word': 'the',
#   'start': 76,
#   'end': 79},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51389706),
#   'index': 20,
#   'word': 'effects',
#   'start': 80,
#   'end': 87},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.58391386),
#   'index': 21,
#   'word': 'on',
#   'start': 88,
#   'end': 90},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5048531),
#   'index': 22,
#   'word': 'co',
#   'start': 91,
#   'end': 93},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53880364),
#   'index': 23,
#   'word': '##gnition',
#   'start': 93,
#   'end': 100},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5564325),
#   'index': 24,
#   'word': 'in',
#   'start': 101,
#   'end': 103},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5327256),
#   'index': 25,
#   'word': 'patients',
#   'start': 104,
#   'end': 112},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5440839),
#   'index': 26,
#   'word': 'with',
#   'start': 113,
#   'end': 117},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5127272),
#   'index': 27,
#   'word': 'mild',
#   'start': 118,
#   'end': 122},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5037226),
#   'index': 28,
#   'word': 'to',
#   'start': 123,
#   'end': 125},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54918253),
#   'index': 29,
#   'word': 'moderate',
#   'start': 126,
#   'end': 134},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5213629),
#   'index': 30,
#   'word': 'Alzheimer',
#   'start': 135,
#   'end': 144},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5229957),
#   'index': 31,
#   'word': "'",
#   'start': 144,
#   'end': 145},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5041516),
#   'index': 32,
#   'word': 's',
#   'start': 145,
#   'end': 146},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5151127),
#   'index': 33,
#   'word': 'disease',
#   'start': 147,
#   'end': 154},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5367256),
#   'index': 34,
#   'word': 'who',
#   'start': 155,
#   'end': 158},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5035394),
#   'index': 35,
#   'word': 'are',
#   'start': 159,
#   'end': 162},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54829246),
#   'index': 36,
#   'word': 'already',
#   'start': 163,
#   'end': 170},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5778916),
#   'index': 37,
#   'word': 'receiving',
#   'start': 171,
#   'end': 180},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5664959),
#   'index': 38,
#   'word': 'an',
#   'start': 181,
#   'end': 183},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53986865),
#   'index': 39,
#   'word': 'ace',
#   'start': 184,
#   'end': 187},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5573736),
#   'index': 40,
#   'word': '##ty',
#   'start': 187,
#   'end': 189},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5079188),
#   'index': 41,
#   'word': '##l',
#   'start': 189,
#   'end': 190},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50183433),
#   'index': 42,
#   'word': '##cho',
#   'start': 190,
#   'end': 193},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.54037905),
#   'index': 43,
#   'word': '##lines',
#   'start': 193,
#   'end': 198},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5102407),
#   'index': 44,
#   'word': '##tera',
#   'start': 198,
#   'end': 202},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5233216),
#   'index': 45,
#   'word': '##se',
#   'start': 202,
#   'end': 204},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5113916),
#   'index': 46,
#   'word': 'inhibitor',
#   'start': 205,
#   'end': 214},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50080556),
#   'index': 47,
#   'word': 'and',
#   'start': 215,
#   'end': 218},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5320789),
#   'index': 48,
#   'word': 'have',
#   'start': 219,
#   'end': 223},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5147626),
#   'index': 49,
#   'word': 'been',
#   'start': 224,
#   'end': 228},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5710467),
#   'index': 50,
#   'word': 'on',
#   'start': 229,
#   'end': 231},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5545301),
#   'index': 51,
#   'word': 'a',
#   'start': 232,
#   'end': 233},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51646817),
#   'index': 52,
#   'word': 'stable',
#   'start': 234,
#   'end': 240},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5377821),
#   'index': 53,
#   'word': 'dose',
#   'start': 241,
#   'end': 245},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5558948),
#   'index': 54,
#   'word': 'for',
#   'start': 246,
#   'end': 249},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5104882),
#   'index': 55,
#   'word': 'at',
#   'start': 250,
#   'end': 252},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5098348),
#   'index': 56,
#   'word': 'least',
#   'start': 253,
#   'end': 258},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5566912),
#   'index': 57,
#   'word': '12',
#   'start': 259,
#   'end': 261},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56151724),
#   'index': 58,
#   'word': 'weeks',
#   'start': 262,
#   'end': 267},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5345537),
#   'index': 59,
#   'word': '.',
#   'start': 267,
#   'end': 268},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5445714),
#   'index': 60,
#   'word': 'Pat',
#   'start': 269,
#   'end': 272},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.546346),
#   'index': 61,
#   'word': '##ients',
#   'start': 272,
#   'end': 277},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53320843),
#   'index': 62,
#   'word': 'will',
#   'start': 278,
#   'end': 282},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52508956),
#   'index': 63,
#   'word': 'be',
#   'start': 283,
#   'end': 285},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.54976386),
#   'index': 64,
#   'word': 'random',
#   'start': 286,
#   'end': 292},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.59298337),
#   'index': 65,
#   'word': '##ized',
#   'start': 292,
#   'end': 296},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5348269),
#   'index': 66,
#   'word': '(',
#   'start': 297,
#   'end': 298},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.56053793),
#   'index': 67,
#   'word': '1',
#   'start': 298,
#   'end': 299},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5009455),
#   'index': 68,
#   'word': ':',
#   'start': 299,
#   'end': 300},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51447904),
#   'index': 69,
#   'word': '1',
#   'start': 300,
#   'end': 301},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5169947),
#   'index': 70,
#   'word': ')',
#   'start': 301,
#   'end': 302},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5690451),
#   'index': 71,
#   'word': 'to',
#   'start': 303,
#   'end': 305},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.557199),
#   'index': 72,
#   'word': 'either',
#   'start': 306,
#   'end': 312},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5149237),
#   'index': 73,
#   'word': 'daily',
#   'start': 313,
#   'end': 318},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5026331),
#   'index': 74,
#   'word': 'dos',
#   'start': 319,
#   'end': 322},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53820586),
#   'index': 75,
#   'word': '##ing',
#   'start': 322,
#   'end': 325},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53758115),
#   'index': 76,
#   'word': 'with',
#   'start': 326,
#   'end': 330},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5185544),
#   'index': 77,
#   'word': '300',
#   'start': 331,
#   'end': 334},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50917256),
#   'index': 78,
#   'word': 'mg',
#   'start': 335,
#   'end': 337},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.558806),
#   'index': 79,
#   'word': 'C',
#   'start': 338,
#   'end': 339},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.57189786),
#   'index': 80,
#   'word': '-',
#   'start': 339,
#   'end': 340},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.55058485),
#   'index': 81,
#   'word': '107',
#   'start': 340,
#   'end': 343},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5099357),
#   'index': 82,
#   'word': '##3',
#   'start': 343,
#   'end': 344},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5220492),
#   'index': 83,
#   'word': 'or',
#   'start': 345,
#   'end': 347},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5271681),
#   'index': 84,
#   'word': 'a',
#   'start': 348,
#   'end': 349},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5211479),
#   'index': 85,
#   'word': 'place',
#   'start': 350,
#   'end': 355},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5221765),
#   'index': 86,
#   'word': '##bo',
#   'start': 355,
#   'end': 357},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.55670416),
#   'index': 87,
#   'word': 'for',
#   'start': 358,
#   'end': 361},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52966356),
#   'index': 88,
#   'word': '16',
#   'start': 362,
#   'end': 364},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54803985),
#   'index': 89,
#   'word': 'weeks',
#   'start': 365,
#   'end': 370},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5291381),
#   'index': 90,
#   'word': '.',
#   'start': 370,
#   'end': 371},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53249216),
#   'index': 91,
#   'word': 'Pat',
#   'start': 372,
#   'end': 375},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5320279),
#   'index': 92,
#   'word': '##ients',
#   'start': 375,
#   'end': 380},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53313375),
#   'index': 93,
#   'word': 'will',
#   'start': 381,
#   'end': 385},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5201048),
#   'index': 94,
#   'word': 'continue',
#   'start': 386,
#   'end': 394},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.56370085),
#   'index': 95,
#   'word': 'the',
#   'start': 395,
#   'end': 398},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5107598),
#   'index': 96,
#   'word': 'stable',
#   'start': 399,
#   'end': 405},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.514063),
#   'index': 97,
#   'word': 'daily',
#   'start': 406,
#   'end': 411},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5464975),
#   'index': 98,
#   'word': 'dose',
#   'start': 412,
#   'end': 416},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.57095253),
#   'index': 99,
#   'word': 'of',
#   'start': 417,
#   'end': 419},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54013366),
#   'index': 100,
#   'word': 'ace',
#   'start': 420,
#   'end': 423},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5562926),
#   'index': 101,
#   'word': '##ty',
#   'start': 423,
#   'end': 425},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5180345),
#   'index': 102,
#   'word': '##l',
#   'start': 425,
#   'end': 426},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51273966),
#   'index': 103,
#   'word': '##cho',
#   'start': 426,
#   'end': 429},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5481054),
#   'index': 104,
#   'word': '##lines',
#   'start': 429,
#   'end': 434},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5159484),
#   'index': 105,
#   'word': '##tera',
#   'start': 434,
#   'end': 438},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.533651),
#   'index': 106,
#   'word': '##se',
#   'start': 438,
#   'end': 440},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50506574),
#   'index': 107,
#   'word': 'inhibitor',
#   'start': 441,
#   'end': 450},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5977485),
#   'index': 108,
#   'word': 'throughout',
#   'start': 451,
#   'end': 461},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5821054),
#   'index': 109,
#   'word': 'the',
#   'start': 462,
#   'end': 465},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5339091),
#   'index': 110,
#   'word': 'study',
#   'start': 466,
#   'end': 471},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51496136),
#   'index': 111,
#   'word': '.',
#   'start': 471,
#   'end': 472},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53183794),
#   'index': 112,
#   'word': 'V',
#   'start': 474,
#   'end': 475},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5493112),
#   'index': 113,
#   'word': '##isi',
#   'start': 475,
#   'end': 478},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.500674),
#   'index': 114,
#   'word': '##ts',
#   'start': 478,
#   'end': 480},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50790626),
#   'index': 115,
#   'word': 'will',
#   'start': 481,
#   'end': 485},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5259972),
#   'index': 116,
#   'word': 'be',
#   'start': 486,
#   'end': 488},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5616538),
#   'index': 117,
#   'word': 'weekly',
#   'start': 489,
#   'end': 495},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53647614),
#   'index': 118,
#   'word': 'at',
#   'start': 496,
#   'end': 498},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52920055),
#   'index': 119,
#   'word': 'the',
#   'start': 499,
#   'end': 502},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52538174),
#   'index': 120,
#   'word': 'beginning',
#   'start': 503,
#   'end': 512},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5937039),
#   'index': 121,
#   'word': 'of',
#   'start': 513,
#   'end': 515},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.55453044),
#   'index': 122,
#   'word': 'the',
#   'start': 516,
#   'end': 519},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50557226),
#   'index': 123,
#   'word': 'study',
#   'start': 520,
#   'end': 525},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5155958),
#   'index': 124,
#   'word': ',',
#   'start': 525,
#   'end': 526},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54377747),
#   'index': 125,
#   'word': 'then',
#   'start': 527,
#   'end': 531},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5027846),
#   'index': 126,
#   'word': 'every',
#   'start': 532,
#   'end': 537},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5339969),
#   'index': 127,
#   'word': 'two',
#   'start': 538,
#   'end': 541},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5669488),
#   'index': 128,
#   'word': 'weeks',
#   'start': 542,
#   'end': 547},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52023095),
#   'index': 129,
#   'word': ',',
#   'start': 547,
#   'end': 548},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52642894),
#   'index': 130,
#   'word': 'and',
#   'start': 549,
#   'end': 552},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50550103),
#   'index': 131,
#   'word': 'every',
#   'start': 553,
#   'end': 558},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5601319),
#   'index': 132,
#   'word': '4',
#   'start': 559,
#   'end': 560},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.59169775),
#   'index': 133,
#   'word': 'weeks',
#   'start': 561,
#   'end': 566},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52246755),
#   'index': 134,
#   'word': 'after',
#   'start': 567,
#   'end': 572},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5249954),
#   'index': 135,
#   'word': 'week',
#   'start': 573,
#   'end': 577},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.51963866),
#   'index': 136,
#   'word': '12',
#   'start': 578,
#   'end': 580},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5030377),
#   'index': 137,
#   'word': '.',
#   'start': 580,
#   'end': 581},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53107864),
#   'index': 138,
#   'word': 'Assessment',
#   'start': 582,
#   'end': 592},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50519574),
#   'index': 139,
#   'word': '##s',
#   'start': 592,
#   'end': 593},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50784403),
#   'index': 140,
#   'word': 'during',
#   'start': 594,
#   'end': 600},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5451517),
#   'index': 141,
#   'word': 'these',
#   'start': 601,
#   'end': 606},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5302779),
#   'index': 142,
#   'word': 'visits',
#   'start': 607,
#   'end': 613},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5014645),
#   'index': 143,
#   'word': 'may',
#   'start': 614,
#   'end': 617},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5269175),
#   'index': 144,
#   'word': 'include',
#   'start': 618,
#   'end': 625},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5167957),
#   'index': 145,
#   'word': 'co',
#   'start': 626,
#   'end': 628},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5078656),
#   'index': 146,
#   'word': '##gnition',
#   'start': 628,
#   'end': 635},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5362378),
#   'index': 147,
#   'word': 'and',
#   'start': 636,
#   'end': 639},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54081404),
#   'index': 148,
#   'word': 'behavior',
#   'start': 640,
#   'end': 648},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53598845),
#   'index': 149,
#   'word': ',',
#   'start': 648,
#   'end': 649},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50314814),
#   'index': 150,
#   'word': 'depression',
#   'start': 650,
#   'end': 660},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5320383),
#   'index': 151,
#   'word': ',',
#   'start': 660,
#   'end': 661},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56246525),
#   'index': 152,
#   'word': 'safety',
#   'start': 662,
#   'end': 668},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54982924),
#   'index': 153,
#   'word': ',',
#   'start': 668,
#   'end': 669},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6249206),
#   'index': 154,
#   'word': 'as',
#   'start': 670,
#   'end': 672},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5800939),
#   'index': 155,
#   'word': 'well',
#   'start': 673,
#   'end': 677},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5444128),
#   'index': 156,
#   'word': 'as',
#   'start': 678,
#   'end': 680},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.535226),
#   'index': 157,
#   'word': 'physical',
#   'start': 681,
#   'end': 689},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56441087),
#   'index': 158,
#   'word': 'exams',
#   'start': 690,
#   'end': 695},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5555838),
#   'index': 159,
#   'word': ',',
#   'start': 695,
#   'end': 696},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.55422723),
#   'index': 160,
#   'word': 'clinical',
#   'start': 697,
#   'end': 705},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5843843),
#   'index': 161,
#   'word': 'laboratory',
#   'start': 706,
#   'end': 716},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5329701),
#   'index': 162,
#   'word': 'tests',
#   'start': 717,
#   'end': 722},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5654287),
#   'index': 163,
#   'word': ',',
#   'start': 722,
#   'end': 723},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50813454),
#   'index': 164,
#   'word': 'E',
#   'start': 724,
#   'end': 725},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53865796),
#   'index': 165,
#   'word': '##K',
#   'start': 725,
#   'end': 726},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5474164),
#   'index': 166,
#   'word': '##G',
#   'start': 726,
#   'end': 727},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5593702),
#   'index': 167,
#   'word': 'and',
#   'start': 728,
#   'end': 731},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50166494),
#   'index': 168,
#   'word': 'adverse',
#   'start': 732,
#   'end': 739},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5052776),
#   'index': 169,
#   'word': 'event',
#   'start': 740,
#   'end': 745},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5308779),
#   'index': 170,
#   'word': 'reporting',
#   'start': 746,
#   'end': 755},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5058054),
#   'index': 171,
#   'word': '.',
#   'start': 755,
#   'end': 756}]

# %%
# Extractzive summarization model
#sum_pipeline = pipeline("summarization",
#  model = "NotXia/pubmedbert-bio-ext-summ",
#  tokenizer = AutoTokenizer.from_pretrained("NotXia/pubmedbert-bio-ext-summ"),
#  trust_remote_code = True,
#  device = 0
#)

# Abstractive summarization model
sum_pipeline = pipeline("summarization", model="L-macc/autotrain-Biomedical_sc_summ-1217846148")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
# Load and process data from clinicaltrials.gov
PROJECT_ROOT = os.path.expanduser('~/Documents/github/biomed_extractor')

# Data directory at top level
DATA_DIR = os.path.join(PROJECT_ROOT, 'data')

df_json = load_trials_json(filepath = DATA_DIR, filename ='example_trials.json')
#print(df_json.head())
mydf = extract_from_clinicaltrials(df_json)
mydf.head()
# Out:
# Loaded 100 records from example_trials.json
#          nctId                                       briefSummary  \
# 0  NCT00105105  The purpose of this study is to evaluate the e...
# 1  NCT00160147  This is a 10-week study with bifeprunox and pl...
# 2  NCT00299988  The overall goal of this double-blind Phase II...
# 3  NCT00334568  Clinical features in patients with the familia...
# 4  NCT00362024  MK0952 is a phosphodiesterase type IV (PDE4) i...
#
#                                  detailedDescription  \
# 0  This will be a double blind, placebo controlle...
# 1
# 2  Abnormal processing of the beta-amyloid protei...
# 3
# 4
#
#                                   inclusion_criteria  \
# 0  diagnosis of alzheimer's disease; women must h...
# 1      diagnosis of dementia of the alzheimer's type
# 2  1. diagnosis of probable alzheimer's disease (...
# 3  meets the national institute of neurological a...
# 4  male or females; age \>/= 55 years, with mild-...
#
#                                   exclusion_criteria  \
# 0  women with an intact uterus; a clinically sign...
# 1  history of seizure disorder; clinically signif...
# 2  1. non-alzheimer dementia.2. active renal dise...
# 3  has a history of or suffers from claustrophobi...
# 4  patients must not be living in nursing home or...
#
#                              intervention_name_clean  \
# 0                                       Mifepristone
# 1                                bifeprunox; Placebo
# 2                Intravenous Immunoglobulin; Placebo
# 3  Rosiglitazone XR (extended release) oral table...
# 4                        MK0952; Comparator: Placebo
#
#                                        outcomes_name
# 0                               effects on cognition
# 1  Brief Psychiatric Rating Scale (BPRS) Total Score
# 2                                     ADAS-Cog; CGIC
# 3  Change in global and regional cerebral glucose...
# 4

# %%
mytext = mydf['detailedDescription'][0]
mytext_list = mytext.split('. ')
print(mytext_list[:5])  # print first 5 sentences
# Out:
# ["This will be a double blind, placebo controlled study of C-1073 to evaluate the effects on cognition in patients with mild to moderate Alzheimer's disease who are already receiving an acetylcholinesterase inhibitor and have been on a stable dose for at least 12 weeks", 'Patients will be randomized (1:1) to either daily dosing with 300 mg C-1073 or a placebo for 16 weeks', 'Patients will continue the stable daily dose of acetylcholinesterase inhibitor throughout the study.\n\nVisits will be weekly at the beginning of the study, then every two weeks, and every 4 weeks after week 12', 'Assessments during these visits may include cognition and behavior, depression, safety, as well as physical exams, clinical laboratory tests, EKG and adverse event reporting.']

# %%
#res_sum = sum_pipeline({"sentences": mytext_list}, strategy="count", strategy_args=2)
res_sum = sum_pipeline(mytext, max_length=50, min_length=25, do_sample=True)
res_sum
# Out:
# [{'summary_text': 'the purpose of this study was to evaluate the effects of acetylcholinesterase inhibitors on cognition in patients with mild to moderate dementia who are already receiving an acetoylcholesterase inhibitor and have been'}]

# %%
parser = PlaintextParser.from_string(mytext, Tokenizer("english"))
summarizer = TextRankSummarizer()
summary = summarizer(parser.document, sentences_count=2)  # number of sentences in summary

for sentence in summary:
    print(sentence)
# Out:
# This will be a double blind, placebo controlled study of C-1073 to evaluate the effects on cognition in patients with mild to moderate Alzheimer's disease who are already receiving an acetylcholinesterase inhibitor and have been on a stable dose for at least 12 weeks.
# Visits will be weekly at the beginning of the study, then every two weeks, and every 4 weeks after week 12.

# %%
res_ner = ner_pipeline(mytext)
res_ner
# Out:
# [{'entity': 'LABEL_0',
#   'score': np.float32(0.59156156),
#   'index': 1,
#   'word': 'This',
#   'start': 0,
#   'end': 4},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.55473566),
#   'index': 2,
#   'word': 'will',
#   'start': 5,
#   'end': 9},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5352636),
#   'index': 3,
#   'word': 'be',
#   'start': 10,
#   'end': 12},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52000993),
#   'index': 4,
#   'word': 'a',
#   'start': 13,
#   'end': 14},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5830644),
#   'index': 5,
#   'word': 'double',
#   'start': 15,
#   'end': 21},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5304068),
#   'index': 6,
#   'word': 'blind',
#   'start': 22,
#   'end': 27},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52235097),
#   'index': 7,
#   'word': ',',
#   'start': 27,
#   'end': 28},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50336933),
#   'index': 8,
#   'word': 'place',
#   'start': 29,
#   'end': 34},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50228494),
#   'index': 9,
#   'word': '##bo',
#   'start': 34,
#   'end': 36},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50752103),
#   'index': 10,
#   'word': 'controlled',
#   'start': 37,
#   'end': 47},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52652115),
#   'index': 11,
#   'word': 'study',
#   'start': 48,
#   'end': 53},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5513958),
#   'index': 12,
#   'word': 'of',
#   'start': 54,
#   'end': 56},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5266094),
#   'index': 13,
#   'word': 'C',
#   'start': 57,
#   'end': 58},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5216667),
#   'index': 14,
#   'word': '-',
#   'start': 58,
#   'end': 59},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5673829),
#   'index': 15,
#   'word': '107',
#   'start': 59,
#   'end': 62},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54353213),
#   'index': 16,
#   'word': '##3',
#   'start': 62,
#   'end': 63},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5437743),
#   'index': 17,
#   'word': 'to',
#   'start': 64,
#   'end': 66},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5413704),
#   'index': 18,
#   'word': 'evaluate',
#   'start': 67,
#   'end': 75},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50962234),
#   'index': 19,
#   'word': 'the',
#   'start': 76,
#   'end': 79},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5128699),
#   'index': 20,
#   'word': 'effects',
#   'start': 80,
#   'end': 87},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5428887),
#   'index': 21,
#   'word': 'on',
#   'start': 88,
#   'end': 90},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.50780797),
#   'index': 22,
#   'word': 'co',
#   'start': 91,
#   'end': 93},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50720286),
#   'index': 23,
#   'word': '##gnition',
#   'start': 93,
#   'end': 100},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6183988),
#   'index': 24,
#   'word': 'in',
#   'start': 101,
#   'end': 103},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5464321),
#   'index': 25,
#   'word': 'patients',
#   'start': 104,
#   'end': 112},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56020284),
#   'index': 26,
#   'word': 'with',
#   'start': 113,
#   'end': 117},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5452451),
#   'index': 27,
#   'word': 'mild',
#   'start': 118,
#   'end': 122},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5138115),
#   'index': 28,
#   'word': 'to',
#   'start': 123,
#   'end': 125},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53922236),
#   'index': 29,
#   'word': 'moderate',
#   'start': 126,
#   'end': 134},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.51247436),
#   'index': 30,
#   'word': 'Alzheimer',
#   'start': 135,
#   'end': 144},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.55695057),
#   'index': 31,
#   'word': "'",
#   'start': 144,
#   'end': 145},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5598809),
#   'index': 32,
#   'word': 's',
#   'start': 145,
#   'end': 146},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52637035),
#   'index': 33,
#   'word': 'disease',
#   'start': 147,
#   'end': 154},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5453861),
#   'index': 34,
#   'word': 'who',
#   'start': 155,
#   'end': 158},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5165674),
#   'index': 35,
#   'word': 'are',
#   'start': 159,
#   'end': 162},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5161372),
#   'index': 36,
#   'word': 'already',
#   'start': 163,
#   'end': 170},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53650105),
#   'index': 37,
#   'word': 'receiving',
#   'start': 171,
#   'end': 180},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52129316),
#   'index': 38,
#   'word': 'an',
#   'start': 181,
#   'end': 183},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.56651443),
#   'index': 39,
#   'word': 'ace',
#   'start': 184,
#   'end': 187},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5097339),
#   'index': 40,
#   'word': '##ty',
#   'start': 187,
#   'end': 189},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5197094),
#   'index': 41,
#   'word': '##l',
#   'start': 189,
#   'end': 190},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53845567),
#   'index': 42,
#   'word': '##cho',
#   'start': 190,
#   'end': 193},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5195148),
#   'index': 43,
#   'word': '##lines',
#   'start': 193,
#   'end': 198},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.58817375),
#   'index': 44,
#   'word': '##tera',
#   'start': 198,
#   'end': 202},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5934831),
#   'index': 45,
#   'word': '##se',
#   'start': 202,
#   'end': 204},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.58845437),
#   'index': 46,
#   'word': 'inhibitor',
#   'start': 205,
#   'end': 214},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50684017),
#   'index': 47,
#   'word': 'and',
#   'start': 215,
#   'end': 218},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54788893),
#   'index': 48,
#   'word': 'have',
#   'start': 219,
#   'end': 223},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.51329803),
#   'index': 49,
#   'word': 'been',
#   'start': 224,
#   'end': 228},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52704185),
#   'index': 50,
#   'word': 'on',
#   'start': 229,
#   'end': 231},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52618694),
#   'index': 51,
#   'word': 'a',
#   'start': 232,
#   'end': 233},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5119371),
#   'index': 52,
#   'word': 'stable',
#   'start': 234,
#   'end': 240},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.55476904),
#   'index': 53,
#   'word': 'dose',
#   'start': 241,
#   'end': 245},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53259075),
#   'index': 54,
#   'word': 'for',
#   'start': 246,
#   'end': 249},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5599061),
#   'index': 55,
#   'word': 'at',
#   'start': 250,
#   'end': 252},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5540798),
#   'index': 56,
#   'word': 'least',
#   'start': 253,
#   'end': 258},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.501674),
#   'index': 57,
#   'word': '12',
#   'start': 259,
#   'end': 261},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.59476304),
#   'index': 58,
#   'word': 'weeks',
#   'start': 262,
#   'end': 267},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53976035),
#   'index': 59,
#   'word': '.',
#   'start': 267,
#   'end': 268},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.62737894),
#   'index': 60,
#   'word': 'Pat',
#   'start': 269,
#   'end': 272},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5714306),
#   'index': 61,
#   'word': '##ients',
#   'start': 272,
#   'end': 277},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56073165),
#   'index': 62,
#   'word': 'will',
#   'start': 278,
#   'end': 282},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5700313),
#   'index': 63,
#   'word': 'be',
#   'start': 283,
#   'end': 285},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54884815),
#   'index': 64,
#   'word': 'random',
#   'start': 286,
#   'end': 292},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5078069),
#   'index': 65,
#   'word': '##ized',
#   'start': 292,
#   'end': 296},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5561691),
#   'index': 66,
#   'word': '(',
#   'start': 297,
#   'end': 298},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51745975),
#   'index': 67,
#   'word': '1',
#   'start': 298,
#   'end': 299},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5430379),
#   'index': 68,
#   'word': ':',
#   'start': 299,
#   'end': 300},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5257297),
#   'index': 69,
#   'word': '1',
#   'start': 300,
#   'end': 301},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56835514),
#   'index': 70,
#   'word': ')',
#   'start': 301,
#   'end': 302},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5297592),
#   'index': 71,
#   'word': 'to',
#   'start': 303,
#   'end': 305},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50024015),
#   'index': 72,
#   'word': 'either',
#   'start': 306,
#   'end': 312},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.51314837),
#   'index': 73,
#   'word': 'daily',
#   'start': 313,
#   'end': 318},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.62834096),
#   'index': 74,
#   'word': 'dos',
#   'start': 319,
#   'end': 322},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.54242975),
#   'index': 75,
#   'word': '##ing',
#   'start': 322,
#   'end': 325},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5444288),
#   'index': 76,
#   'word': 'with',
#   'start': 326,
#   'end': 330},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5618438),
#   'index': 77,
#   'word': '300',
#   'start': 331,
#   'end': 334},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5636444),
#   'index': 78,
#   'word': 'mg',
#   'start': 335,
#   'end': 337},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5380817),
#   'index': 79,
#   'word': 'C',
#   'start': 338,
#   'end': 339},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5380369),
#   'index': 80,
#   'word': '-',
#   'start': 339,
#   'end': 340},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5860005),
#   'index': 81,
#   'word': '107',
#   'start': 340,
#   'end': 343},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.57219744),
#   'index': 82,
#   'word': '##3',
#   'start': 343,
#   'end': 344},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54148877),
#   'index': 83,
#   'word': 'or',
#   'start': 345,
#   'end': 347},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5131034),
#   'index': 84,
#   'word': 'a',
#   'start': 348,
#   'end': 349},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52374506),
#   'index': 85,
#   'word': 'place',
#   'start': 350,
#   'end': 355},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5103343),
#   'index': 86,
#   'word': '##bo',
#   'start': 355,
#   'end': 357},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.51276314),
#   'index': 87,
#   'word': 'for',
#   'start': 358,
#   'end': 361},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50099117),
#   'index': 88,
#   'word': '16',
#   'start': 362,
#   'end': 364},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5898028),
#   'index': 89,
#   'word': 'weeks',
#   'start': 365,
#   'end': 370},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5401856),
#   'index': 90,
#   'word': '.',
#   'start': 370,
#   'end': 371},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6191645),
#   'index': 91,
#   'word': 'Pat',
#   'start': 372,
#   'end': 375},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56173766),
#   'index': 92,
#   'word': '##ients',
#   'start': 375,
#   'end': 380},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56961954),
#   'index': 93,
#   'word': 'will',
#   'start': 381,
#   'end': 385},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5045389),
#   'index': 94,
#   'word': 'continue',
#   'start': 386,
#   'end': 394},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5254206),
#   'index': 95,
#   'word': 'the',
#   'start': 395,
#   'end': 398},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5193347),
#   'index': 96,
#   'word': 'stable',
#   'start': 399,
#   'end': 405},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5094581),
#   'index': 97,
#   'word': 'daily',
#   'start': 406,
#   'end': 411},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53499466),
#   'index': 98,
#   'word': 'dose',
#   'start': 412,
#   'end': 416},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5416748),
#   'index': 99,
#   'word': 'of',
#   'start': 417,
#   'end': 419},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5608672),
#   'index': 100,
#   'word': 'ace',
#   'start': 420,
#   'end': 423},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5017394),
#   'index': 101,
#   'word': '##ty',
#   'start': 423,
#   'end': 425},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52427286),
#   'index': 102,
#   'word': '##l',
#   'start': 425,
#   'end': 426},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5230136),
#   'index': 103,
#   'word': '##cho',
#   'start': 426,
#   'end': 429},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5310252),
#   'index': 104,
#   'word': '##lines',
#   'start': 429,
#   'end': 434},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.600699),
#   'index': 105,
#   'word': '##tera',
#   'start': 434,
#   'end': 438},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6066684),
#   'index': 106,
#   'word': '##se',
#   'start': 438,
#   'end': 440},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6075685),
#   'index': 107,
#   'word': 'inhibitor',
#   'start': 441,
#   'end': 450},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5271772),
#   'index': 108,
#   'word': 'throughout',
#   'start': 451,
#   'end': 461},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5155951),
#   'index': 109,
#   'word': 'the',
#   'start': 462,
#   'end': 465},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5041528),
#   'index': 110,
#   'word': 'study',
#   'start': 466,
#   'end': 471},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54410076),
#   'index': 111,
#   'word': '.',
#   'start': 471,
#   'end': 472},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.583604),
#   'index': 112,
#   'word': 'V',
#   'start': 474,
#   'end': 475},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.52096355),
#   'index': 113,
#   'word': '##isi',
#   'start': 475,
#   'end': 478},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5151414),
#   'index': 114,
#   'word': '##ts',
#   'start': 478,
#   'end': 480},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5651254),
#   'index': 115,
#   'word': 'will',
#   'start': 481,
#   'end': 485},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5558157),
#   'index': 116,
#   'word': 'be',
#   'start': 486,
#   'end': 488},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.55202013),
#   'index': 117,
#   'word': 'weekly',
#   'start': 489,
#   'end': 495},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53568304),
#   'index': 118,
#   'word': 'at',
#   'start': 496,
#   'end': 498},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5368386),
#   'index': 119,
#   'word': 'the',
#   'start': 499,
#   'end': 502},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5134016),
#   'index': 120,
#   'word': 'beginning',
#   'start': 503,
#   'end': 512},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5468529),
#   'index': 121,
#   'word': 'of',
#   'start': 513,
#   'end': 515},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5188127),
#   'index': 122,
#   'word': 'the',
#   'start': 516,
#   'end': 519},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.51188207),
#   'index': 123,
#   'word': 'study',
#   'start': 520,
#   'end': 525},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5575925),
#   'index': 124,
#   'word': ',',
#   'start': 525,
#   'end': 526},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53961986),
#   'index': 125,
#   'word': 'then',
#   'start': 527,
#   'end': 531},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.54698503),
#   'index': 126,
#   'word': 'every',
#   'start': 532,
#   'end': 537},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5419801),
#   'index': 127,
#   'word': 'two',
#   'start': 538,
#   'end': 541},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.60685456),
#   'index': 128,
#   'word': 'weeks',
#   'start': 542,
#   'end': 547},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56145513),
#   'index': 129,
#   'word': ',',
#   'start': 547,
#   'end': 548},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5390923),
#   'index': 130,
#   'word': 'and',
#   'start': 549,
#   'end': 552},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5404993),
#   'index': 131,
#   'word': 'every',
#   'start': 553,
#   'end': 558},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5106019),
#   'index': 132,
#   'word': '4',
#   'start': 559,
#   'end': 560},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.6077218),
#   'index': 133,
#   'word': 'weeks',
#   'start': 561,
#   'end': 566},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.53431904),
#   'index': 134,
#   'word': 'after',
#   'start': 567,
#   'end': 572},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.6308063),
#   'index': 135,
#   'word': 'week',
#   'start': 573,
#   'end': 577},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5036424),
#   'index': 136,
#   'word': '12',
#   'start': 578,
#   'end': 580},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5403973),
#   'index': 137,
#   'word': '.',
#   'start': 580,
#   'end': 581},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5389117),
#   'index': 138,
#   'word': 'Assessment',
#   'start': 582,
#   'end': 592},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.5007493),
#   'index': 139,
#   'word': '##s',
#   'start': 592,
#   'end': 593},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.52682567),
#   'index': 140,
#   'word': 'during',
#   'start': 594,
#   'end': 600},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6137014),
#   'index': 141,
#   'word': 'these',
#   'start': 601,
#   'end': 606},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5250432),
#   'index': 142,
#   'word': 'visits',
#   'start': 607,
#   'end': 613},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5695999),
#   'index': 143,
#   'word': 'may',
#   'start': 614,
#   'end': 617},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5846618),
#   'index': 144,
#   'word': 'include',
#   'start': 618,
#   'end': 625},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5594341),
#   'index': 145,
#   'word': 'co',
#   'start': 626,
#   'end': 628},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53860444),
#   'index': 146,
#   'word': '##gnition',
#   'start': 628,
#   'end': 635},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5341075),
#   'index': 147,
#   'word': 'and',
#   'start': 636,
#   'end': 639},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5222966),
#   'index': 148,
#   'word': 'behavior',
#   'start': 640,
#   'end': 648},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5611644),
#   'index': 149,
#   'word': ',',
#   'start': 648,
#   'end': 649},
#  {'entity': 'LABEL_1',
#   'score': np.float32(0.50338155),
#   'index': 150,
#   'word': 'depression',
#   'start': 650,
#   'end': 660},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5560799),
#   'index': 151,
#   'word': ',',
#   'start': 660,
#   'end': 661},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5314818),
#   'index': 152,
#   'word': 'safety',
#   'start': 662,
#   'end': 668},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.55981326),
#   'index': 153,
#   'word': ',',
#   'start': 668,
#   'end': 669},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.6070524),
#   'index': 154,
#   'word': 'as',
#   'start': 670,
#   'end': 672},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5567231),
#   'index': 155,
#   'word': 'well',
#   'start': 673,
#   'end': 677},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.58843845),
#   'index': 156,
#   'word': 'as',
#   'start': 678,
#   'end': 680},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5231287),
#   'index': 157,
#   'word': 'physical',
#   'start': 681,
#   'end': 689},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5392979),
#   'index': 158,
#   'word': 'exams',
#   'start': 690,
#   'end': 695},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5691246),
#   'index': 159,
#   'word': ',',
#   'start': 695,
#   'end': 696},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.53027266),
#   'index': 160,
#   'word': 'clinical',
#   'start': 697,
#   'end': 705},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.594206),
#   'index': 161,
#   'word': 'laboratory',
#   'start': 706,
#   'end': 716},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56220615),
#   'index': 162,
#   'word': 'tests',
#   'start': 717,
#   'end': 722},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5760348),
#   'index': 163,
#   'word': ',',
#   'start': 722,
#   'end': 723},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.64142865),
#   'index': 164,
#   'word': 'E',
#   'start': 724,
#   'end': 725},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.57008475),
#   'index': 165,
#   'word': '##K',
#   'start': 725,
#   'end': 726},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5788758),
#   'index': 166,
#   'word': '##G',
#   'start': 726,
#   'end': 727},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5995461),
#   'index': 167,
#   'word': 'and',
#   'start': 728,
#   'end': 731},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.56853974),
#   'index': 168,
#   'word': 'adverse',
#   'start': 732,
#   'end': 739},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.5365426),
#   'index': 169,
#   'word': 'event',
#   'start': 740,
#   'end': 745},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.51209027),
#   'index': 170,
#   'word': 'reporting',
#   'start': 746,
#   'end': 755},
#  {'entity': 'LABEL_0',
#   'score': np.float32(0.54192233),
#   'index': 171,
#   'word': '.',
#   'start': 755,
#   'end': 756}]

# %%
# function to provide model a text to run PICO extraction/sumamrization on. In this case, either brief summary or detailed description
def compose_trial_text(row):
    text = row['briefSummary']
    if pd.notna(row['detailedDescription']) and row['detailedDescription'].strip():
        text += " " + row['detailedDescription']
    return text

def chunk_text_by_chars(text, chunk_char_length=1200, overlap=100):
    start = 0
    n_chars = len(text)
    while start < n_chars:
        end = min(start + chunk_char_length, n_chars)
        yield text[start:end]
        if end == n_chars:
            break
        start = end - overlap  # overlap for entities at borders

def run_ner_on_long_text(text, ner_pipeline, chunk_char_length=1200, overlap=100):
    entities = []
    for chunk in chunk_text_by_chars(text, chunk_char_length, overlap):
        ents = ner_pipeline(chunk)
        entities.extend(ents)
    return entities

def clean_population_entities(pop_entities):
    # Accept entities longer than X char, containing at least one demographic or diagnosis word
    min_len = 8
    demo_kw = ['patients', 'subjects', 'adults', 'children', 'individuals', 'men', 'women','male','female', 'participants']
    result = []
    for ent in pop_entities:
        ent_clean = ent.strip().strip(';,')
        if len(ent_clean) < min_len:
            continue
        if any(kw in ent_clean.lower() for kw in demo_kw):
            result.append(ent_clean)
    # Remove exact duplicates
    return '; '.join(sorted(set(result)))

def merge_entities(entities):
    """
    Merge adjacent tokens of the same entity_group into full phrases using start/end char indices.
    entities: List of dicts, each with 'entity_group', 'word', 'start', 'end'
    Returns: dict of entity_group -> list of phrases
    """
    if not entities:
        return {}

    # Sort by character start position for safety
    entities = sorted(entities, key=lambda x: x['start'])
    merged = []
    current = None

    for ent in entities:
        if (current is None or
            ent['entity_group'] != current['entity_group'] or
            ent['start'] != current['end']):   # must be adjacent

            # Start new entity
            if current:
                merged.append(current)
            current = {
                'entity_group': ent['entity_group'],
                'word': ent['word'],
                'start': ent['start'],
                'end': ent['end']
            }
        else:
            # Extend current entity
            current['word'] += ' ' + ent['word']
            current['end'] = ent['end']
    if current:
        merged.append(current)
    return merged

def extract_pico_from_merged_entities(entities):
    pico_dict = {"participants": [], "intervention": [], "comparator": [], "outcome": []}
    for ent in entities:
        group = ent['entity_group'].lower()
        if group in pico_dict:
            pico_dict[group].append(ent['word'])
    # join multiple same-type entities per doc
    return {k: "; ".join(sorted(set(v))) if v else "" for k, v in pico_dict.items()}

import re
from difflib import SequenceMatcher

GENERIC_WORDS = {'medications', 'treatment', 'antipsychotics', 'antidepressants'}

def normalize_intervention(ent):
    ent = ent.lower().strip()
    ent = re.sub(r"\(([^\)]*)\)", "", ent)
    ent = re.sub(r"[^\w\s]", " ", ent)
    ent = re.sub(r"\s+", " ", ent)
    ent = re.sub(r"\bor\b.*$", "", ent)
    ent = re.sub(r"\band\b.*$", "", ent)
    ent = ent.strip()
    return ent

def is_substring_duplicate(e, deduped):
    for existing in deduped:
        if e != existing and (e in existing or existing in e):
            return True
    return False

def deduplicate_intervention_entities(entities, threshold=0.85):
    cleaned = [normalize_intervention(e) for e in entities if len(e.strip()) > 2]
    cleaned = [ent for ent in cleaned if ent and ent not in GENERIC_WORDS]
    final = []
    for cand in cleaned:
        if not is_substring_duplicate(cand, final) and \
           not any(SequenceMatcher(None, cand, d).ratio() > threshold for d in final):
            final.append(cand)
    return "; ".join(sorted(final))

def summarize_textRank(text):
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summarizer = TextRankSummarizer()
    summary = summarizer(parser.document, sentences_count=2)  # number of sentences in summary
    return ' '.join(str(sentence) for sentence in summary)

# %%
def extract_comparator(interventions):
    """
    Returns the first matching comparator keyword if found in interventions string, else ''.
    """
    if not isinstance(interventions, str):
        return ''
    comparators = [
        'placebo', 'standard care', 'usual care', 'sham', 'control',
        'standard therapy', 'vehicle', 'observation only', 'waitlist',
        'best supportive care'
    ]
    interventions_lower = interventions.lower()
    for comp in comparators:
        if comp in interventions_lower:
            return comp
    return ''



def remove_comparator_terms(interventions):
    if not isinstance(interventions, str):
        return interventions
    comparators = [
        'placebo', 'standard care', 'usual care', 'sham', 'control',
        'standard therapy', 'vehicle', 'observation only', 'waitlist',
        'best supportive care'
    ]
    # Split, trim, remove comparators, filter empty
    parts = [p.strip() for p in interventions.split(';')]
    cleaned = [p for p in parts if p and p.lower() not in comparators]
    return '; '.join(cleaned)

def clean_outcomes(outcome_str):
    if not isinstance(outcome_str, str):
        return ''
    # Replace brackets, backslashes, asterisks, colons, slashes, parentheses, commas with space or nothing
    cleaned = re.sub(r'[\[\]()*\\/:#]', '', outcome_str)
    cleaned = re.sub(r'\s+', ' ', cleaned)   # Multiple spaces to one
    cleaned = cleaned.replace(' ,', ',').replace(' ;', ';')
    cleaned = cleaned.lower().strip()
    # Split on semicolon
    outcomes = [o.strip(' .;,-') for o in cleaned.split(';')]
    # Remove empty, deduplicate and join
    outcomes = list(dict.fromkeys([o for o in outcomes if o and len(o) > 1]))  
    return '; '.join(outcomes)

    return cleaned.strip('; ').strip()

# %%
def process_trials(df, ner_pipeline):
    pop, intervention, outcome, summary = [], [], [], []
    for _, row in df.iterrows():
        main_text = compose_trial_text(row)
        inclusion_text = row.get("inclusion_criteria", "")

        # Only run NER on desired fields for each PICO
        main_entities = merge_entities(run_ner_on_long_text(main_text, ner_pipeline))
        inclusion_entities = merge_entities(run_ner_on_long_text(str(inclusion_text), ner_pipeline))

        pico_main = extract_pico_from_merged_entities(main_entities)
        pico_inc = extract_pico_from_merged_entities(inclusion_entities)

        # Population: from inclusion_criteria, Intervention/Outcome: from main text
        cleaned_population = clean_population_entities(pico_inc["participants"].split(";")) if pico_inc["participants"] else ""

        pop.append(cleaned_population)
        raw_interventions = pico_main["intervention"].split(";") if pico_main["intervention"] else []
        cleaned_intervention = deduplicate_intervention_entities(raw_interventions)
        intervention.append(cleaned_intervention)

        outcome.append(pico_main["outcome"])

        summary2sent = summarize_textRank(main_text)
        summary.append(summary2sent)

    df["population_extracted"] = pop
    df["intervention_extracted"] = intervention
    df["outcome_extracted"] = outcome
    
    # clean up columns
    df['outcome_extracted'] = df['outcome_extracted'].apply(clean_outcomes)
    # Apply extract_comparator to the intervention_extracted column
    df['comparator_extracted'] = df['intervention_extracted'].apply(extract_comparator)
    # Clean the intervention_extracted column by removing found comparators    
    df['intervention_extracted'] = df['intervention_extracted'].apply(remove_comparator_terms)
    # add main text summary to the dataframe
    df["summary_extracted"] = summary

    return df

# %%
ner_res = process_trials(mydf, ner_pipeline)
ner_res.head()
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ner_res = process_trials(mydf, ner_pipeline)
#       2 ner_res.head()
#
# Cell In[8], line 8, in process_trials(df, ner_pipeline)
#       5 inclusion_text = row.get("inclusion_criteria", "")
#       7 # Only run NER on desired fields for each PICO
# ----> 8 main_entities = merge_entities(run_ner_on_long_text(main_text, ner_pipeline))
#       9 inclusion_entities = merge_entities(run_ner_on_long_text(str(inclusion_text), ner_pipeline))
#      11 pico_main = extract_pico_from_merged_entities(main_entities)
#
# Cell In[6], line 62, in merge_entities(entities)
#      59     if current:
#      60         merged.append(current)
#      61     current = {
# ---> 62         'entity_group': ent['entity_group'],
#      63         'word': ent['word'],
#      64         'start': ent['start'],
#      65         'end': ent['end']
#      66     }
#      67 else:
#      68     # Extend current entity
#      69     current['word'] += ' ' + ent['word']
#
# KeyError: 'entity_group'

# %%
for i in range(52):
    print(f"Trial {i+1}:")
    print(f"{ner_res['outcome_extracted'][i]}")
    #print("-" * 40)
# Out:
# Trial 1:
# cognition and behavior, depression, safety, as well as physical exams, clinical laboratory tests, ekg and adverse event reporting.
# Trial 2:
#
# Trial 3:
# cognitive, behavioral and functional measures; safety, efficacy
# Trial 4:
#
# Trial 5:
#
# Trial 6:
#
# Trial 7:
#
# Trial 8:
# 123; brain regional distribution volumes; plasma; time to the peak uptake and amplitude of the peak uptake; tissue
# Trial 9:
# oxidative damage
# Trial 10:
# brain regional distribution volumes; peak uptake
# Trial 11:
# amplitude of; brain regional distribution volumes; peak uptake
# Trial 12:
# efficacy; safety
# Trial 13:
#
# Trial 14:
# efficacy; safety
# Trial 15:
# assessment of patient accommodation status and caregiver burden ( apas carb ); cognitive decline; effectiveness; mini - mental state examination ( mmse ) ; the disability assessment in dementia ( dad ) ; and; mortality rate; safety; vital status and institutionalization status, adverse events, vital signs, weight, physical and neurologic examinations
# Trial 16:
#
# Trial 17:
# cognitive,; safety and tolerability
# Trial 18:
# cognition and behavioural symptoms; cognitive and behavioural symptoms; functional
# Trial 19:
# efficacy and safety; safety
# Trial 20:
# safety and tolerability
# Trial 21:
# safety and tolerability
# Trial 22:
# safety and tolerability
# Trial 23:
# biomarkers; efficacy and; efficacy and safety; memory deficit
# Trial 24:
# safety and tolerability
# Trial 25:
#
# Trial 26:
# : apathy inventory patient and caregiver version changes, observation scale changes, frequency and severity of the other bpsd using the npi, qualitative analysis of the nursing home staff behavioural changes; apathy inventory clinician score changes *
# Trial 27:
#
# Trial 28:
#
# Trial 29:
#
# Trial 30:
# acceptability
# Trial 31:
# safety, biodistribution, and dosimetry
# Trial 32:
# safety, biodistribution, and dosimetry
# Trial 33:
# alzheimer ' s disease assessment scale cognitive subscale ( adas - cog ) score; alzheimer ' s disease cooperative study activities of daily living inventory ( adcs - adl ) score; brain amyloid protein load; csf concentrations of amyloid - β related peptides, total tau, and phosphorylated tau ( p - tau ); efficacy and safety
# Trial 34:
# - cog; ada; alzheimer ' s disease assessment scale - cognitive subscale; cognition; efficacy and safety
# Trial 35:
#
# Trial 36:
# cognitive decline
# Trial 37:
# clinical and biomarker; pharmacokinetics; safety; therapeutic efficacy
# Trial 38:
# efficacy and safety
# Trial 39:
# global brain atrophy
# Trial 40:
# cognitive function
# Trial 41:
# cohen - mansfield agitation inventory \ [ cmai \ ] total score; efficacy; efficacy and safety
# Trial 42:
# pharmacokinetics; safety, tolerability
# Trial 43:
# effectiveness; safety, efficacy, pharmacokinetics, and pharmacodynamics; safety, tolerability and
# Trial 44:
# 13; efficacy and safety; item alzheimer ' s disease assessment scale - cognitive subscale ( adas - cog13 )
# Trial 45:
# safety and efficacy
# Trial 46:
# safety and efficacy
# Trial 47:
# diagnostic performance; quality
# Trial 48:
# / quality of life scores; safety; safety and toxicity / adverse events; size; toxicity / adverse events
# Trial 49:
# safety
# Trial 50:
# safe; tolerable
# Trial 51:
#
# Trial 52:
# clinical dementia rating - sum of boxes ( cdr - sb ) score; clinical progression; cognitive and functional impairment; mini - mental state examination ( mmse ), ad assessment scale - cognitive subscale ( 13 items ) \ [ adas - cog 13 \ ], and ad cooperative study - activities of daily living inventory ( mild cognitive impairment version ) \ [ adcs - adl - mci \ ]
